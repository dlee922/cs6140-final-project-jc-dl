# %%
import pandas as pd

# %%
X_combined = pd.read_csv("../data/processed/X_combined.csv")
ids = ['patientId', 'sampleId', 'GENE_PANEL']
X_combined = X_combined.drop(columns=ids)
X_combined
# Out:
#      AGE_AT_DOS_BX  CSTAGE  PSTAGE  CIGARETTE_HX_Never  NEOADJUVANT_Yes  \
# 0        52.917808       1       3               False            False
# 1        65.087671       3       3                True             True
# 2        64.947945       1       2               False            False
# 3        83.178082       1       2                True            False
# 4        75.008219       2       1               False             True
# ..             ...     ...     ...                 ...              ...
# 450      62.764384       1       2               False            False
# 451      70.597260       1       1               False            False
# 452      51.293151       3       2               False             True
# 453      71.747945       2       3                True            False
# 454      62.695890       2       3               False            False
#
#      RACE_Black  RACE_Other  RACE_White  SEX_Male  \
# 0         False       False        True     False
# 1         False       False        True      True
# 2         False       False       False      True
# 3         False       False        True     False
# 4         False       False        True     False
# ..          ...         ...         ...       ...
# 450       False       False        True     False
# 451       False       False        True     False
# 452       False       False        True     False
# 453       False       False        True      True
# 454       False       False        True     False
#
#      PREDOM_HISTO_SUBTYPE_Lepidic  ...  MSI_SCORE  MUTATION_COUNT    PLOIDY  \
# 0                           False  ...       0.08               4  2.535049
# 1                           False  ...       0.90               3  2.634823
# 2                           False  ...       0.08               6  3.611512
# 3                           False  ...       4.39               4  2.895438
# 4                           False  ...       0.00               8  2.423386
# ..                            ...  ...        ...             ...       ...
# 450                         False  ...       0.31               6  4.202858
# 451                         False  ...       0.43              12  2.805596
# 452                         False  ...       0.00               9  1.788676
# 453                         False  ...       0.00               2  2.410862
# 454                         False  ...       0.06              11  2.141613
#
#        PURITY  TMB_NONSYNONYMOUS  CELL_CYCLE_Yes  IS_WGD_1  \
# 0    0.348728           4.436621           False     False
# 1    0.369512           3.327466           False      True
# 2    0.320492           6.654932            True      True
# 3    0.556694           4.436621            True      True
# 4    0.374035           8.873242           False      True
# ..        ...                ...             ...       ...
# 450  0.353128           5.188189           False      True
# 451  0.484608          10.376377           False     False
# 452  0.322383           7.782283           False     False
# 453  0.300000           1.729396           False     False
# 454  0.197416           9.511679           False     False
#
#      MSI_TYPE_Indeterminate  MSI_TYPE_Instable  MSI_TYPE_Stable
# 0                     False              False             True
# 1                     False              False             True
# 2                     False              False             True
# 3                      True              False            False
# 4                     False              False             True
# ..                      ...                ...              ...
# 450                   False              False             True
# 451                   False              False             True
# 452                   False              False             True
# 453                   False              False             True
# 454                   False              False             True
#
# [455 rows x 69 columns]

# %%
X_combined['TP53_x_EGFR'] = X_combined['TP53'] * X_combined['EGFR']
X_combined['KEAP1_x_STK11'] = X_combined['KEAP1'] * X_combined['STK11']
X_combined['KEAP1_x_KRAS'] = X_combined['KEAP1'] * X_combined['KRAS']
X_combined['KRAS_x_STK11'] = X_combined['KRAS'] * X_combined['STK11']
X_combined['FGA_x_TP53'] = X_combined['FGA'] * X_combined['TP53']
X_combined['FGA_x_ERBB2'] = X_combined['FGA'] * X_combined['ERBB2']
X_combined['smoking_x_KRAS'] = (1 - X_combined['CIGARETTE_HX_Never']) * X_combined['KRAS']
X_combined['smoking_x_SMARCA4'] = (1 - X_combined['CIGARETTE_HX_Never']) * X_combined['SMARCA4']
X_combined['smoking_x_TP53'] = (1 - X_combined['CIGARETTE_HX_Never']) * X_combined['TP53']
X_combined['PSTAGE_x_SMARCA4'] = X_combined['PSTAGE'] * X_combined['SMARCA4']
X_combined['PSTAGE_x_TP53'] = X_combined['PSTAGE'] * X_combined['TP53']
X_combined['PSTAGE_x_neoadjuvant'] = X_combined['PSTAGE'] * X_combined['NEOADJUVANT_Yes']
interaction_cols = [col for col in X_combined.columns if '_x_' in col]

# %%
for col in interaction_cols:
    print(col, X_combined[col].value_counts())
# Out:
# TP53_x_EGFR TP53_x_EGFR
# 0.0    383
# 1.0     72
# Name: count, dtype: int64
# KEAP1_x_STK11 KEAP1_x_STK11
# 0.0    410
# 1.0     45
# Name: count, dtype: int64
# KEAP1_x_KRAS KEAP1_x_KRAS
# 0.0    419
# 1.0     36
# Name: count, dtype: int64
# KRAS_x_STK11 KRAS_x_STK11
# 0.0    406
# 1.0     49
# Name: count, dtype: int64
# FGA_x_TP53 FGA_x_TP53
# 0.000000    270
# 1.000000      2
# 0.724551      1
# 0.412422      1
# 0.652029      1
#            ...
# 0.210742      1
# 0.578746      1
# 0.946808      1
# 0.313980      1
# 0.575601      1
# Name: count, Length: 185, dtype: int64
# FGA_x_ERBB2 FGA_x_ERBB2
# 0.000000    436
# 0.764632      1
# 0.618106      1
# 0.867514      1
# 0.265908      1
# 0.025367      1
# 0.356694      1
# 0.217237      1
# 0.901927      1
# 0.559796      1
# 0.548549      1
# 0.364283      1
# 0.665973      1
# 0.137521      1
# 0.168836      1
# 0.661677      1
# 0.870472      1
# 0.478558      1
# 0.539141      1
# 0.227138      1
# Name: count, dtype: int64
# smoking_x_KRAS smoking_x_KRAS
# 0.0    297
# 1.0    158
# Name: count, dtype: int64
# AGE_AT_DOS_BX_x_SEX_Male AGE_AT_DOS_BX_x_SEX_Male
# 0.000000     314
# 72.128767      2
# 72.306849      2
# 65.087671      1
# 64.947945      1
#             ...
# 71.967123      1
# 85.657534      1
# 52.380822      1
# 70.369863      1
# 71.747945      1
# Name: count, Length: 140, dtype: int64
# PSTAGE_x_SMARCA4 PSTAGE_x_SMARCA4
# 0.0    424
# 3.0     14
# 1.0     11
# 2.0      6
# Name: count, dtype: int64
# PSTAGE_x_TP53 PSTAGE_x_TP53
# 0.0    270
# 1.0    100
# 3.0     49
# 2.0     36
# Name: count, dtype: int64
# smoking_x_SMARCA4 smoking_x_SMARCA4
# 0.0    429
# 1.0     26
# Name: count, dtype: int64
# smoking_x_TP53 smoking_x_TP53
# 0.0    308
# 1.0    147
# Name: count, dtype: int64
# PSTAGE_x_neoadjuvant PSTAGE_x_neoadjuvant
# 0    411
# 3     26
# 1      9
# 2      9
# Name: count, dtype: int64

# %%
X_combined.to_csv('../data/processed/X_combined_interact.csv')
